# %%
import requests
from bs4 import BeautifulSoup
import json
# Search keyword
search_keyword = 'embroidery'  # Replace with the desired keyword

# URL to search for public groups containing the keyword
url = f'https://www.googleapis.com/customsearch/v1?key=AIzaSyDmzZ5B86WPjcUpBghQ-F2Gg95T0dHmAiE&cx=a6e44c78f3a844486&q={search_keyword}'

# Make the GET request to the Facebook Graph API
response = requests.get(url).json()

linkSet = set()
postDict = {}

def htmlToJson(url):
    response = requests.get(url, headers = {'User-Agent': 'Mozilla/5.0'})
    if response.status_code != 200:
        return {"error": f"failed to retrieve url"}
    soup = BeautifulSoup(response.content, "html.parser")

    data = {
        "title": soup.title.string if soup.title else "no title",
        "headings": [h1.get_text(strip=True) for h1 in soup.find_all('h1')],
        "paragraphs": [p.get_text(strip=True) for p in soup.find_all('p')],
        "links": [{"text": a.get_text(strip =True), "url": a['href']} for a in soup.find_all('a', href=True)],
        "list_items":[li.get_text(strip=True) for li in soup.find_all('li')]
    }

    json_data=json.dumps(data, indent=4)
    return json_data

for i in response['items']:
    # imageLink = i['pagemap']
    # imageLink = imageLink['cse_image'][0]
    # infoDict[i['title']] = imageLink['src']
    
    if '/p/' not in i['link']:
        linkSet.add(i['link'])
    
print(linkSet)
    
for i in linkSet:
    response2 = htmlToJson(i)
    # response2.raise_for_status()
    # if response2.status_code != 204:
    #     print(response2.text)
    #postDict[i] = 
    print(response2)


# for i in linkSet:
#     print(i)
# Out:
# {'https://www.instagram.com/apprvl/', 'https://www.instagram.com/flynn_and_mabel/', 'https://www.instagram.com/stitchingsabbatical/', 'https://www.instagram.com/dirtyneedleembroidery/', 'https://www.instagram.com/thebarmyfox/', 'https://www.instagram.com/olandercoembroidery/', 'https://www.instagram.com/embroiderycode/', 'https://www.instagram.com/elliemac.embroidery/', 'https://www.instagram.com/dandelion.doiley.embroidery/'}
# {
#     "title": "Login \u2022 Instagram",
#     "headings": [],
#     "paragraphs": [],
#     "links": [],
#     "list_items": []
# }
# {
#     "title": "Login \u2022 Instagram",
#     "headings": [],
#     "paragraphs": [],
#     "links": [],
#     "list_items": []
# }
# {
#     "title": "Login \u2022 Instagram",
#     "headings": [],
#     "paragraphs": [],
#     "links": [],
#     "list_items": []
# }
# {
#     "title": "Login \u2022 Instagram",
#     "headings": [],
#     "paragraphs": [],
#     "links": [],
#     "list_items": []
# }
# {
#     "title": "Login \u2022 Instagram",
#     "headings": [],
#     "paragraphs": [],
#     "links": [],
#     "list_items": []
# }
# {
#     "title": "Login \u2022 Instagram",
#     "headings": [],
#     "paragraphs": [],
#     "links": [],
#     "list_items": []
# }
# {
#     "title": "Login \u2022 Instagram",
#     "headings": [],
#     "paragraphs": [],
#     "links": [],
#     "list_items": []
# }
# {
#     "title": "Login \u2022 Instagram",
#     "headings": [],
#     "paragraphs": [],
#     "links": [],
#     "list_items": []
# }
# {
#     "title": "Login \u2022 Instagram",
#     "headings": [],
#     "paragraphs": [],
#     "links": [],
#     "list_items": []
# }
