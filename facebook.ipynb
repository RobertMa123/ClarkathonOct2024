# %%
import requests

# Search keyword
search_keyword = 'bass'  # Replace with the desired keyword

# URL to search for public groups containing the keyword
url = f'https://www.googleapis.com/customsearch/v1?key=AIzaSyDmzZ5B86WPjcUpBghQ-F2Gg95T0dHmAiE&cx=70c8a26a4782b4147&q={search_keyword}+facebook+group'

# Make the GET request to the Facebook Graph API
response = requests.get(url).json()

# %%
response
# Out:
# {'kind': 'customsearch#search',
#  'url': {'type': 'application/json',
#   'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json'},
#  'queries': {'request': [{'title': 'Google Custom Search - bass facebook group',
#     'totalResults': '15500000',
#     'searchTerms': 'bass facebook group',
#     'count': 10,
#     'startIndex': 1,
#     'inputEncoding': 'utf8',
# ...

# %%
response["items"][0]["pagemap"]["metatags"][0]["og:description"]
# Out:
# 'PLEASE BE AWARE THAT IF YOU HAVE NO AFFILIATION WITH BERKLEE, OR DO NOT CONTRIBUTE REGULARLY TO THIS SITE, AND YOU POST SIMPLY TO SELL MUSIC, \nINSTRUMENTS, OR ANYTHING ELSE, OR PROMOTE YOUR MUSIC...'

# %%
import facebook as f
f.get_groups("pie")
# Out:
#                                                 name  \
# 0       TRENTON NJ - AUTHENTIC TOMATO PIE - Facebook
# 1       South Shore Bar Pizza Social Club | Facebook
# 2       TRENTON NJ - AUTHENTIC TOMATO PIE - Facebook
# 3  Facebook Groups | Cajun Seafood Pot pie. Turne...
# 4  Facebook Groups | I need a really good small b...
#
#                                          description
# 0  This group is dedicated to the Trenton NJ Auth...
# 1  Devoted to our love of South Shore-style bar p...
# 2  This group is dedicated to the Trenton NJ Auth...
# 3        Cajun Seafood Pot pie.  Turned out perfect!
# 4  I need a really good small banana cream pie th...
